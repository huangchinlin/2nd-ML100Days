# %% [markdown]
# ## 作業1
#
# 1. 選擇的資料集: https://www.kaggle.com/bigquery/google-analytics-sample
# 2. 對於電商網站而言, 這份資料集的重要性在於可藉由分析GA的數據能夠獲得訪客的特性與行為, 做為提升銷量方案的設計與檢討的基礎.
# 3. 此資料集透過google bigquery api收集而來, 資料型態為CSV.
# 4. 提升銷量的評估可以應用幾個指標間的闗係進行
#    4.1 訪客地區 與 成交金額
#    4.2 特定日期 與 成交金額
#    4.3 訪問裝罝 與 成交金額
#    4.4 訪問方式 與 成交金額
#    4.5 產品 與 成交金額

# %% [markdown]
# ## 作業2
#
# 1. 假設 提高業績 = 縮短客戶待車時間(提高回流率) + 提高車輛稼動率
# 2. 資料可從APP進行收集, 包括地理資訊, 叫車時間, 搭車時間, 指定車型等, 存儲在結構化資料庫.
#    2.1 地理資訊: 用來分析客戶與區域性的關係, 找出區域熱點
#    2.2 叫車時間: 用來分析區域與時間的關係, 找出時間+區域熱點, 預先引導車輛在週遭區域待命
#    2.3 指定車型: 用來分析客戶與車型的關係
# 3. 透過客戶平均待車時間(上車時間-叫車時間), 舊客回頭比率的關係, 營業額比較, 以及車輛空車待命時間進行評估.

# %% [markdown]
# ## 作業3
#
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    mse = sum((y - yp)**2) / len(y)
    return mse

# %%
def mean_absolute_error(y, yp):
    mae = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 245.485
# The Mean absolute error is 12.061
